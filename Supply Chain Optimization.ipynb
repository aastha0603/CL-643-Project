# %%
import pandas as pd
from pulp import *

# %%
# !pip install openpyxl

# %% [markdown]
# ## Plant Location

# %% [markdown]
# #### Manufacturing variable costs

# %%
# Import Costs
manvar_costs = pd.read_excel('variable_costs.xlsx', index_col = 0)
manvar_costs
# Out:
#                          USA  Germany  Japan  Brazil  India
# Variable Costs ($/Unit)
# USA                       12       12     12      12     12
# Germany                   13       13     13      13     13
# Japan                     10       10     10      10     10
# Brazil                     8        8      8       8      8
# India                      5        5      5       5      5

# %% [markdown]
# #### Freight costs

# %%
# Import Costs
freight_costs = pd.read_excel('freight_costs.xlsx', index_col = 0)
freight_costs
# Out:
#                                USA  Germany  Japan  Brazil  India
# Freight Costs ($/Container)
# USA                              0    12250   1100   16100   8778
# Germany                      13335        0   8617   20244  10073
# Japan                        15400    22750      0   43610  14350
# Brazil                       16450    22050  28000       0  29750
# India                        13650    15400  24500   29400      0

# %% [markdown]
# #### Variable Costs

# %%
# Variable Costs
var_cost = freight_costs/1000 + manvar_costs 

var_cost
# Out:
#                                 USA  Germany   Japan  Brazil   India
# Freight Costs ($/Container)
# USA                          12.000    24.25  13.100  28.100  20.778
# Germany                      26.335    13.00  21.617  33.244  23.073
# Japan                        25.400    32.75  10.000  53.610  24.350
# Brazil                       24.450    30.05  36.000   8.000  37.750
# India                        18.650    20.40  29.500  34.400   5.000

# %% [markdown]
# #### Fixed Costs

# %%
# Import Costs
fixed_costs = pd.read_excel('fixed_cost.xlsx', index_col = 0)
fixed_costs
# Out:
#           Low  High
# USA      6500  9500
# Germany  4980  7270
# Japan    6230  9100
# Brazil   3230  4730
# India    2110  6160

# %% [markdown]
# #### Plants Capacity

# %%
# Two types of plants: Low Capacity and High Capacity Plant
cap = pd.read_excel('capacity.xlsx', index_col = 0)
cap
# Out:
#                          Low  High
# Capacity (kUnits/month)
# USA                      500  1500
# Germany                  500  1500
# Japan                    500  1500
# Brazil                   500  1500
# India                    500  3000

# %% [markdown]
# #### Demand

# %%
# -- Demand
demand = pd.read_excel('demand_3.xlsx', index_col = 0)
demand
# Out:
#                 Demand
# (Units/month)
# USA            2800000
# Germany         550000
# Japan                0
# Brazil               0
# India           239000

# %%
# Define Decision Variables
loc = ['USA', 'Germany', 'Japan', 'Brazil', 'India']
size = ['Low', 'High']

# Initialize Class
model = LpProblem("Capacitated Plant Location Model", LpMinimize)


# Create Decision Variables
x = LpVariable.dicts("production_", [(i,j) for i in loc for j in loc],
                     lowBound=0, upBound=None, cat='continuous')
y = LpVariable.dicts("plant_", 
                     [(i,s) for s in size for i in loc], cat='Binary')

# Define Objective Function
model += (lpSum([fixed_costs.loc[i,s] * y[(i,s)] * 1000 for s in size for i in loc])
          + lpSum([var_cost.loc[i,j] * x[(i,j)]   for i in loc for j in loc]))

# Add Constraints
for j in loc:
    model += lpSum([x[(i, j)] for i in loc]) == demand.loc[j,'Demand']
for i in loc:
    model += lpSum([x[(i, j)] for j in loc]) <= lpSum([cap.loc[i,s]*y[(i,s)] * 1000
                                                       for s in size])


# Define logical constraint: Add a logical constraint so that if the high capacity plant in USA is open, then a low capacity plant in Germany is also opened.
# model += y[('USA','High_Cap')] <= y[('Germany','Low_Cap')]                                                       
                                                       
# Solve Model
model.solve()
print("Total Costs = {:,} ($/Month)".format(int(value(model.objective))))
print('\n' + "Status: {}".format(LpStatus[model.status]))


# Dictionnary
dict_plant = {}
dict_prod = {}
for v in model.variables():
    if 'plant' in v.name:
        name = v.name.replace('plant__', '').replace('_', '')
        dict_plant[name] = int(v.varValue)
        p_name = name
    else:
        name = v.name.replace('production__', '').replace('_', '')
        dict_prod[name] = v.varValue
    print(name, "=", v.varValue)
# Out:
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /home/animesh/.local/lib/python3.8/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/9552d3cbcf104db1b42e655d61b7fc4f-pulp.mps timeMode elapsed branch printingOptions all solution /tmp/9552d3cbcf104db1b42e655d61b7fc4f-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 15 COLUMNS
# At line 131 RHS
# At line 142 BOUNDS
# At line 153 ENDATA
# Problem MODEL has 10 rows, 35 columns and 60 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 6.59157e+07 - 0.00 seconds
# Cgl0004I processed model has 8 rows, 25 columns (10 integer (10 of which binary)) and 40 elements
# Cbc0038I Initial state - 2 integers unsatisfied sum - 0.853667
# Cbc0038I Pass   1: suminf.    0.00000 (0) obj. 7.032e+07 iterations 5
# Cbc0038I Solution found of 7.032e+07
# Cbc0038I Relaxing continuous gives 7.032e+07
# Cbc0038I Before mini branch and bound, 8 integers at bound fixed and 11 continuous
# Cbc0038I Full problem 8 rows 25 columns, reduced to 1 rows 2 columns
# Cbc0038I Mini branch and bound did not improve solution (0.00 seconds)
# Cbc0038I Round again with cutoff of 6.98796e+07
# Cbc0038I Reduced cost fixing fixed 3 variables on major pass 2
# Cbc0038I Pass   2: suminf.    0.07150 (1) obj. 6.98796e+07 iterations 4
# Cbc0038I Pass   3: suminf.    0.30367 (1) obj. 6.98796e+07 iterations 5
# Cbc0038I Pass   4: suminf.    0.30367 (1) obj. 6.98796e+07 iterations 0
# Cbc0038I Pass   5: suminf.    0.47033 (1) obj. 6.98796e+07 iterations 1
# Cbc0038I Pass   6: suminf.    0.41403 (1) obj. 6.98796e+07 iterations 4
# Cbc0038I Pass   7: suminf.    0.47033 (1) obj. 6.98796e+07 iterations 2
# Cbc0038I Pass   8: suminf.    0.49335 (2) obj. 6.98796e+07 iterations 3
# Cbc0038I Pass   9: suminf.    0.49335 (2) obj. 6.98796e+07 iterations 0
# Cbc0038I Pass  10: suminf.    0.66519 (2) obj. 6.98796e+07 iterations 3
# Cbc0038I Pass  11: suminf.    0.49335 (2) obj. 6.98796e+07 iterations 3
# Cbc0038I Pass  12: suminf.    0.49335 (2) obj. 6.98796e+07 iterations 0
# Cbc0038I Pass  13: suminf.    0.49335 (2) obj. 6.98796e+07 iterations 0
# Cbc0038I Pass  14: suminf.    0.77301 (3) obj. 6.98796e+07 iterations 1
# Cbc0038I Pass  15: suminf.    0.77301 (3) obj. 6.98796e+07 iterations 1
# Cbc0038I Pass  16: suminf.    0.85526 (3) obj. 6.98796e+07 iterations 2
# Cbc0038I Pass  17: suminf.    0.57568 (3) obj. 6.98796e+07 iterations 4
# Cbc0038I Pass  18: suminf.    0.39267 (1) obj. 6.98796e+07 iterations 5
# Cbc0038I Pass  19: suminf.    0.46162 (2) obj. 6.98796e+07 iterations 3
# Cbc0038I Pass  20: suminf.    0.46162 (2) obj. 6.98796e+07 iterations 0
# Cbc0038I Pass  21: suminf.    0.39267 (1) obj. 6.98796e+07 iterations 3
# Cbc0038I Pass  22: suminf.    0.46162 (2) obj. 6.98796e+07 iterations 3
# Cbc0038I Pass  23: suminf.    0.57568 (3) obj. 6.98796e+07 iterations 2
# Cbc0038I Pass  24: suminf.    0.46162 (2) obj. 6.98796e+07 iterations 4
# Cbc0038I Pass  25: suminf.    0.46162 (2) obj. 6.98796e+07 iterations 0
# Cbc0038I Pass  26: suminf.    0.95461 (2) obj. 6.98796e+07 iterations 3
# Cbc0038I Pass  27: suminf.    0.69437 (2) obj. 6.98796e+07 iterations 4
# Cbc0038I Pass  28: suminf.    0.95461 (2) obj. 6.98796e+07 iterations 3
# Cbc0038I Pass  29: suminf.    0.72994 (2) obj. 6.98796e+07 iterations 2
# Cbc0038I Pass  30: suminf.    0.58163 (2) obj. 6.98796e+07 iterations 4
# Cbc0038I Pass  31: suminf.    0.58163 (2) obj. 6.98796e+07 iterations 1
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 4 integers at bound fixed and 7 continuous
# Cbc0038I Full problem 8 rows 25 columns, reduced to 5 rows 12 columns
# Cbc0038I Mini branch and bound did not improve solution (0.00 seconds)
# Cbc0038I After 0.00 seconds - Feasibility pump exiting with objective of 7.032e+07 - took 0.00 seconds
# Cbc0012I Integer solution of 70320000 found by feasibility pump after 0 iterations and 0 nodes (0.00 seconds)
# Cbc0038I Full problem 8 rows 25 columns, reduced to 6 rows 11 columns
# Cbc0031I 1 added rows had average density of 3
# Cbc0013I At root node, 2 cuts changed objective from 65915747 to 70320000 in 2 passes
# Cbc0014I Cut generator 0 (Probing) - 1 row cuts average 2.0 elements, 1 column cuts (1 active)  in 0.000 seconds - new frequency is 1
# Cbc0014I Cut generator 1 (Gomory) - 2 row cuts average 9.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is 1
# Cbc0014I Cut generator 2 (Knapsack) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 3 (Clique) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (MixedIntegerRounding2) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 5 (FlowCover) - 1 row cuts average 2.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is 1
# Cbc0014I Cut generator 6 (TwoMirCuts) - 3 row cuts average 3.7 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is 1
# Cbc0001I Search completed - best objective 70320000, took 4 iterations and 0 nodes (0.00 seconds)
# Cbc0035I Maximum depth 0, 8 variables fixed on reduced cost
# Cuts at root node changed objective from 6.59157e+07 to 7.032e+07
# Probing was tried 2 times and created 2 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 2 times and created 2 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 2 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 2 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 2 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 2 times and created 1 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 2 times and created 3 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                70320000.00000000
# Enumerated nodes:               0
# Total iterations:               4
# Time (CPU seconds):             0.01
# Time (Wallclock seconds):       0.01
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.01   (Wallclock seconds):       0.01
#
# Total Costs = 70,320,000 ($/Month)
#
# Status: Optimal
# ('Brazil','High') = 0.0
# ('Brazil','Low') = 0.0
# ('Germany','High') = 0.0
# ('Germany','Low') = 0.0
# ('India','High') = 1.0
# ('India','Low') = 0.0
# ('Japan','High') = 0.0
# ('Japan','Low') = 0.0
# ('USA','High') = 1.0
# ('USA','Low') = 0.0
# ('Brazil','Brazil') = 0.0
# ('Brazil','Germany') = 0.0
# ('Brazil','India') = 0.0
# ('Brazil','Japan') = 0.0
# ('Brazil','USA') = 0.0
# ('Germany','Brazil') = 0.0
# ('Germany','Germany') = 0.0
# ('Germany','India') = 0.0
# ('Germany','Japan') = 0.0
# ('Germany','USA') = 0.0
# ('India','Brazil') = 0.0
# ('India','Germany') = 550000.0
# ('India','India') = 239000.0
# ('India','Japan') = 0.0
# ('India','USA') = 1300000.0
# ('Japan','Brazil') = 0.0
# ('Japan','Germany') = 0.0
# ('Japan','India') = 0.0
# ('Japan','Japan') = 0.0
# ('Japan','USA') = 0.0
# ('USA','Brazil') = 0.0
# ('USA','Germany') = 0.0
# ('USA','India') = 0.0
# ('USA','Japan') = 0.0
# ('USA','USA') = 1500000.0
# /home/animesh/.local/lib/python3.8/site-packages/pulp/pulp.py:1352: UserWarning: Spaces are not permitted in the name. Converted to '_'
#   warnings.warn("Spaces are not permitted in the name. Converted to '_'")

# %%
# Capacity Plant
list_low, list_high = [], []
for l in loc:
    for cap in ['Low', 'High']:
        x = "('{}','{}')".format(l, cap)
        if cap == 'Low':
            list_low.append(dict_plant[x])
        else:
            list_high.append(dict_plant[x])
df_capacity = pd.DataFrame({'Location': loc, 'Low': list_low, 'High': list_high}).set_index('Location')
    
df_capacity
# Out:
#           Low  High
# Location
# USA         0     1
# Germany     0     0
# Japan       0     0
# Brazil      0     0
# India       0     1
